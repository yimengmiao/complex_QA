# %% [markdown]
# # 项目测评背景
# 随着人工智能技术的快速发展，学术论文的数量和复杂性呈指数级增长，如何高效、准确地从海量文献中提取关键信息成为科研人员和行业从业者面临的重大挑战。传统的文献检索和阅读方式已难以满足需求，而现有的大多数问答系统仍局限于对结构化知识库或短文本的浅层解析，无法深入理解学术论文中的复杂逻辑、实验数据和理论推导。为此，东南大学和华为诺亚方舟实验室联合推出《人工智能领域论文复杂问题问答评测》，旨在推动自然语言处理技术在学术文献深度理解与推理方面的突破。本评测任务要求参赛系统基于给定的英文论文全文，回答与之相关的多项选择题，其中每个问题包含一个以上的正确答案，从而考验模型在长文本理解、多跳推理和批判性分析等方面的综合能力。
#
# 本评测的核心挑战在于学术论文的独特复杂性——论文通常包含密集的专业术语、复杂的数学公式、跨段落的理论论证以及多维度的实验结果。参赛模型不仅需要准确识别文本中的显性信息，还需整合图表数据、方法描述和实验结论，甚至推断作者未明确陈述的隐含观点。例如，一个问题可能要求系统判断某篇论文提出的方法在特定条件下是否优于基线模型，而答案可能需要结合方法章节的理论分析、实验部分的对比表格以及讨论章节的局限性说明才能得出。此外，多选题的设计进一步增加了任务的难度，因为部分选项可能看似合理但缺乏严格依据，或仅在特定条件下成立，这就要求大模型具备高度的逻辑严谨性和抗干扰能力。我们期望通过这一评测，激发学术界和工业界对复杂学术文本理解技术的探索，并为智能文献综述、科研助手等应用提供技术支撑。
#
# 本评测的独特之处在于其紧密结合真实学术场景的需求，与传统的知识图谱问答或开放域问答相比，更强调对非结构化长文本的深度语义解析和高阶推理能力。同时，多选题的设定更容易评估。我们精心构建的数据集涵盖85篇人工智能顶会顶刊论文和225道人工智能专业博士生标注的多选题，问题类型包括实验验证、理论推导和结论分析等，确保全面评估模型的综合性能。为促进大模型在学术领域相关技术的发展，东南大学华为诺亚方舟实验室在CCKS2025大会组织本次评测任务。

# %% [markdown]
# ## Simple Demo
# 接下来将会使用chatgpt提供的file api,上传文件，通过检测 multi_choice_questions.json中paper_id对chatgpt进行调用提问。

# %%
# !pip install openai
# !pip install dotenv
# !pip install --upgrade openai

# %%
import os
import json
import time
import openai
from openai import OpenAI
print(openai.__version__)
from dotenv import load_dotenv
load_dotenv('D:\\workspace\\pycharm_project\\paper-parser\\.env')

# 创建 OpenAI 客户端
client = OpenAI(
    api_key=os.getenv('OPENAI_API_KEY'),
    base_url=os.getenv('OPENAI_URL')  # 如果使用自定义 URL
)

SYS_PROMPT="""You are an excellent paper analyzer. You will be provided with a PDF file of a research paper.
Your task is to thoroughly read and analyze the paper's content, including text, images, and tables.
Subsequently, you will be asked to determine if a given definition related to the paper is correct.
If and only if you are uncertain about a definition, you should endeavor to find evidence within the paper, potentially hidden in its tables or images, to support your answer.
Please reply in the following JSON format:
{
    "answer": "your answer, correct or incorrect",
    "reason": "your reason"
}
"""
# print(os.getenv('OPENAI_URL'))
# print(os.getenv('OPENAI_API_KEY'))

demo_file = "D:\\workspace\\pycharm_project\\paper-parser\\papers\\0\\2024.acl-long.820.pdf"
paper_base_path = "D:\\workspace\\pycharm_project\\paper-parser\\papers\\"
answers_file = "D:\\workspace\\pycharm_project\\paper-parser\\analysis_answers.json"
final_formatted_answers_file = "D:\\workspace\\pycharm_project\\paper-parser\\analysis_answers_formatted.json"

wait_time = 6
def parse_question(question):
    question = question["question"]
    q = question.split("\n")[0]

    # 获取所有非空行
    lines = [line.strip() for line in question.split("\n") if line.strip()]
    
    # 第一行是问题，剩下的是选项
    if len(lines) > 1:
        all_options = lines[1:]
    else:
        return q, []
    
    # 找到所有选项的起始位置
    option_starts = {}  # {选项字母: 在all_options中的索引}
    
    for i, line in enumerate(all_options):
        for letter in ['A', 'B', 'C', 'D']:
            if (line.startswith(f"{letter}.") or line.startswith(f"{letter} ")) and letter not in option_starts:
                option_starts[letter] = i
                break
    
    # 按A, B, C, D顺序构建完整的选项
    ordered_definitions = []
    expected_order = ['A', 'B', 'C', 'D']
    
    for i, letter in enumerate(expected_order):
        if letter not in option_starts:
            # 如果缺少某个选项，返回空列表
            return q, []
        
        # 确定当前选项的内容范围
        start_idx = option_starts[letter]
        
        # 找到下一个选项的起始位置（或结束位置）
        if i + 1 < len(expected_order):
            next_letter = expected_order[i + 1]
            if next_letter in option_starts:
                end_idx = option_starts[next_letter]
            else:
                end_idx = len(all_options)
        else:
            end_idx = len(all_options)
        
        # 合并从start_idx到end_idx-1的所有行
        option_content = []
        for j in range(start_idx, end_idx):
            option_content.append(all_options[j])
        
        # 将多行合并为一行，用空格连接
        full_option = " ".join(option_content)
        ordered_definitions.append(full_option)
    
    # 确保我们有且仅有4个定义
    if len(ordered_definitions) == 4:
        return q, ordered_definitions
    else:
        return q, []

def remove_markdown(text):
    """
    去除markdown格式
    """
    return text.replace("```json", "").replace("```", "")

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

def formatted_answer(answers):
    formatted_answers = []
    for a in answers:
        correct_answer = ''
        for choice in a.keys():
            if choice in ['A', 'B', 'C', 'D']:
                if a[choice]["answer"] == "correct":
                    correct_answer += choice
        formatted_answer = {
            "paper_id":  a["paper_id"],
            "question":  a["question"],
            "correct_answer": correct_answer
        }
        formatted_answers.append(formatted_answer)
    return formatted_answers

def to_file(answers=None, formatted_answers=None):
    if answers is not None:
        with open(answers_file,  "w", encoding="utf-8"):
            json.dump(answers, open(answers_file, "w", encoding="utf-8"), indent=2, ensure_ascii=False)
            print(f"✅ 已保存分析结果到 {answers_file}")
    if formatted_answers is not None:
        with open(final_formatted_answers_file,  "w", encoding="utf-8"):
            json.dump(formatted_answers, open(final_formatted_answers_file, "w", encoding="utf-8"), indent=2, ensure_ascii=False)
            print(f"✅ 已保存格式化答案到 {final_formatted_answers_file}")
# Out:
# 1.84.0

# %%
# 详细检查 OpenAI 客户端的可用功能
import sys
print("Python 路径:", sys.executable)
print("OpenAI 版本:", openai.__version__)

print("\n=== 检查 client 的可用属性 ===")
print("client 的主要属性:", [attr for attr in dir(client) if not attr.startswith('_')])

print("\n=== 检查 client.beta 的可用属性 ===")
try:
    beta_attrs = [attr for attr in dir(client.beta) if not attr.startswith('_')]
    print("client.beta 的属性:", beta_attrs)
except Exception as e:
    print("❌ client.beta 不存在:", str(e))

print("\n=== 测试各个 API ===")
try:
    # 测试 vector_stores
    vs = client.beta.vector_stores
    print("✅ client.beta.vector_stores 存在")
    print("vector_stores 的方法:", [attr for attr in dir(vs) if not attr.startswith('_')])
except AttributeError as e:
    print("❌ client.beta.vector_stores 不存在:", str(e))

try:
    # 测试 assistants
    assistants = client.beta.assistants
    print("✅ client.beta.assistants 存在")
    print("assistants 的方法:", [attr for attr in dir(assistants) if not attr.startswith('_')])
except AttributeError as e:
    print("❌ client.beta.assistants 不存在:", str(e))

try:
    # 测试 threads
    threads = client.beta.threads
    print("✅ client.beta.threads 存在")
    print("threads 的方法:", [attr for attr in dir(threads) if not attr.startswith('_')])
except AttributeError as e:
    print("❌ client.beta.threads 不存在:", str(e))

# 检查是否有其他名称的向量存储API
print("\n=== 查找可能的向量存储相关API ===")
for attr in dir(client.beta):
    if not attr.startswith('_') and 'vector' in attr.lower():
        print(f"找到可能的向量API: {attr}")

# 检查完整的client结构
print("\n=== client的完整结构 ===")
print("检查client是否有其他向量相关的API...")
for attr in dir(client):
    if not attr.startswith('_') and ('vector' in attr.lower() or 'store' in attr.lower()):
        print(f"找到: client.{attr}")
# Out:
# Python 路径: D:\Soft\tools\miniconda\python.exe
# OpenAI 版本: 1.84.0
#
# === 检查 client 的可用属性 ===
# client 的主要属性: ['api_key', 'audio', 'auth_headers', 'base_url', 'batches', 'beta', 'chat', 'close', 'completions', 'containers', 'copy', 'custom_auth', 'default_headers', 'default_query', 'delete', 'embeddings', 'evals', 'files', 'fine_tuning', 'get', 'get_api_list', 'images', 'is_closed', 'max_retries', 'models', 'moderations', 'organization', 'patch', 'platform_headers', 'post', 'project', 'put', 'qs', 'request', 'responses', 'timeout', 'uploads', 'user_agent', 'vector_stores', 'websocket_base_url', 'with_options', 'with_raw_response', 'with_streaming_response']
#
# === 检查 client.beta 的可用属性 ===
# client.beta 的属性: ['assistants', 'chat', 'realtime', 'threads', 'with_raw_response', 'with_streaming_response']
#
# === 测试各个 API ===
# ❌ client.beta.vector_stores 不存在: 'Beta' object has no attribute 'vector_stores'
# ✅ client.beta.assistants 存在
# assistants 的方法: ['create', 'delete', 'list', 'retrieve', 'update', 'with_raw_response', 'with_streaming_response']
# ✅ client.beta.threads 存在
# threads 的方法: ['create', 'create_and_run', 'create_and_run_poll', 'create_and_run_stream', 'delete', 'messages', 'retrieve', 'runs', 'update', 'with_raw_response', 'with_streaming_response']
#
# === 查找可能的向量存储相关API ===
#
# === client的完整结构 ===
# 检查client是否有其他向量相关的API...
# 找到: client.vector_stores

# %%
class PaperAnalyzer:
    def __init__(self):
        self.uploaded_files = {}  # 存储已上传的文件 {file_path: file_id}
        self.vector_stores = {}   # 存储已创建的vector store {file_path: vector_store_id}
        self.assistants = {}      # 存储已创建的助手 {vector_store_id: assistant_id}

    def get_or_upload_file(self, file_path):
        """获取或上传文件，避免重复上传"""
        if file_path in self.uploaded_files:
            print(f"♻️ 复用已上传的文件: {self.uploaded_files[file_path]}")
            return self.uploaded_files[file_path]

        print(f"🔄 首次上传文件: {file_path}")
        file_response = client.files.create(
            file=open(file_path, "rb"),
            purpose="assistants"
        )
        file_id = file_response.id
        self.uploaded_files[file_path] = file_id
        print(f"✅ 文件上传完成: {file_id}")
        return file_id

    def get_or_create_vector_store(self, file_path, store_name):
        """获取或创建vector store，避免重复创建"""
        if file_path in self.vector_stores:
            # print(f"♻️ 复用已有的 Vector Store: {self.vector_stores[file_path]}")
            return self.vector_stores[file_path]

        print(f"🔄 创建新的 Vector Store: {store_name}")
        vector_store = client.vector_stores.create(name=store_name)
        vector_store_id = vector_store.id

        # 上传文件到vector store
        file_batch = client.vector_stores.file_batches.upload_and_poll(
            vector_store_id=vector_store_id,
            files=[open(file_path, "rb")]
        )

        self.vector_stores[file_path] = vector_store_id
        print(f"✅ Vector Store 创建完成: {vector_store_id}, 状态: {file_batch.status}")
        return vector_store_id

    def get_or_create_assistant(self, vector_store_id, file_id):
        """获取或创建助手，避免重复创建"""
        if vector_store_id in self.assistants:
            # print(f"♻️ 复用已有的助手: {self.assistants[vector_store_id]}")
            return self.assistants[vector_store_id]

        print("🔄 创建新的助手...")
        try:
            # 首先尝试使用正式API
            try:
                assistant = client.assistants.create(
                    name="Paper Analyzer",
                    description="A paper reader",
                    instructions=SYS_PROMPT,
                    model="gpt-4-turbo",
                    tools=[
                        {"type": "file_search"},
                        {"type": "code_interpreter"}
                    ],
                    tool_resources={
                        "file_search": {"vector_store_ids": [vector_store_id]},
                        "code_interpreter": {"file_ids": [file_id]}
                    }
                )
                print("✅ 使用正式 assistants API 创建成功")
            except AttributeError:
                # 如果正式API不存在，回退到beta API
                # print("⚠️ 正式 assistants API 不存在，使用 beta API")
                assistant = client.beta.assistants.create(
                    name="Paper Analyzer",
                    description="A paper reader",
                    instructions=SYS_PROMPT,
                    model="gpt-4-turbo",
                    tools=[
                        {"type": "file_search"},
                        {"type": "code_interpreter"}
                    ],
                    tool_resources={
                        "file_search": {"vector_store_ids": [vector_store_id]},
                        "code_interpreter": {"file_ids": [file_id]}
                    }
                )
                print("✅ 使用 beta assistants API 创建成功")

            assistant_id = assistant.id
            self.assistants[vector_store_id] = assistant_id
            print(f"✅ 助手创建完成: {assistant_id}")
            return assistant_id
        except Exception as e:
            print(f"❌ 创建助手失败: {e}")
            # 尝试其他模型
            try:
                print("🔄 尝试使用 gpt-4-turbo...")
                try:
                    assistant = client.assistants.create(
                        name="Paper Analyzer",
                        description="A paper reader",
                        instructions=SYS_PROMPT,
                        model="gpt-4-turbo",
                        tools=[
                            {"type": "file_search"},
                            {"type": "code_interpreter"}
                        ],
                        tool_resources={
                            "file_search": {"vector_store_ids": [vector_store_id]},
                            "code_interpreter": {"file_ids": [file_id]}
                        }
                    )
                    # print("✅ 使用正式 assistants API 创建成功 (gpt-4-turbo)")
                except AttributeError:
                    assistant = client.beta.assistants.create(
                        name="Paper Analyzer",
                        description="A paper reader",
                        instructions=SYS_PROMPT,
                        model="gpt-4-turbo",
                        tools=[
                            {"type": "file_search"},
                            {"type": "code_interpreter"}
                        ],
                        tool_resources={
                            "file_search": {"vector_store_ids": [vector_store_id]},
                            "code_interpreter": {"file_ids": [file_id]}
                        }
                    )
                    # print("✅ 使用 beta assistants API 创建成功 (gpt-4-turbo)")

                assistant_id = assistant.id
                self.assistants[vector_store_id] = assistant_id
                print(f"✅ 助手创建完成 (gpt-4-turbo): {assistant_id}")
                return assistant_id
            except Exception as e2:
                print(f"❌ 所有模型都失败了: {e2}")
                return None

    def create_thread(self):
        """创建对话线程，优先使用正式API"""
        try:
            # 首先尝试使用正式API
            try:
                thread = client.threads.create()
                # print(f"✅ 使用正式 threads API 创建线程: {thread.id}")
                return thread
            except AttributeError:
                # 如果正式API不存在，回退到beta API
                # print("⚠️ 正式 threads API 不存在，使用 beta API")
                thread = client.beta.threads.create()
                # print(f"✅ 使用 beta threads API 创建线程: {thread.id}")
                return thread
        except Exception as e:
            print(f"❌ 创建线程失败: {e}")
            return None

    def send_message(self, thread_id, content):
        """发送消息，优先使用正式API"""
        try:
            # 首先尝试使用正式API
            try:
                message = client.threads.messages.create(
                    thread_id=thread_id,
                    role="user",
                    content=content
                )
                return message
            except AttributeError:
                # 如果正式API不存在，回退到beta API
                message = client.beta.threads.messages.create(
                    thread_id=thread_id,
                    role="user",
                    content=content
                )
                return message
        except Exception as e:
            print(f"❌ 发送消息失败: {e}")
            return None

    def run_assistant(self, thread_id, assistant_id):
        """运行助手，优先使用正式API"""
        try:
            # 首先尝试使用正式API
            try:
                run = client.threads.runs.create(
                    thread_id=thread_id,
                    assistant_id=assistant_id
                )
                return run
            except AttributeError:
                # 如果正式API不存在，回退到beta API
                run = client.beta.threads.runs.create(
                    thread_id=thread_id,
                    assistant_id=assistant_id
                )
                return run
        except Exception as e:
            print(f"❌ 运行助手失败: {e}")
            return None

    def get_run_status(self, thread_id, run_id):
        """获取运行状态，优先使用正式API"""
        try:
            # 首先尝试使用正式API
            try:
                run_status = client.threads.runs.retrieve(
                    thread_id=thread_id,
                    run_id=run_id
                )
                return run_status
            except AttributeError:
                # 如果正式API不存在，回退到beta API
                run_status = client.beta.threads.runs.retrieve(
                    thread_id=thread_id,
                    run_id=run_id
                )
                return run_status
        except Exception as e:
            print(f"❌ 获取运行状态失败: {e}")
            return None

    def get_messages(self, thread_id):
        """获取消息列表，优先使用正式API"""
        try:
            # 首先尝试使用正式API
            try:
                messages = client.threads.messages.list(thread_id=thread_id)
                return messages
            except AttributeError:
                # 如果正式API不存在，回退到beta API
                messages = client.beta.threads.messages.list(thread_id=thread_id)
                return messages
        except Exception as e:
            print(f"❌ 获取消息失败: {e}")
            return None

    def cleanup_resources(self):
        """清理创建的资源"""
        print("🧹 清理资源...")

        # 删除助手
        for assistant_id in self.assistants.values():
            try:
                try:
                    client.assistants.delete(assistant_id)
                    print(f"🗑️ 已删除助手 (正式API): {assistant_id}")
                except AttributeError:
                    client.beta.assistants.delete(assistant_id)
                    print(f"🗑️ 已删除助手 (beta API): {assistant_id}")
            except:
                pass

        # 删除vector stores
        for vector_store_id in self.vector_stores.values():
            try:
                client.vector_stores.delete(vector_store_id)
                print(f"🗑️ 已删除 Vector Store: {vector_store_id}")
            except:
                pass

        # 删除上传的文件
        for file_id in self.uploaded_files.values():
            try:
                client.files.delete(file_id)
                print(f"🗑️ 已删除文件: {file_id}")
            except:
                pass

        print("✅ 资源清理完成")
# 为 PaperAnalyzer 类添加按论文ID清理资源的功能
class PaperAnalyzerEnhanced(PaperAnalyzer):
    def __init__(self):
        super().__init__()
        self.paper_resources = {}  # 存储每个论文ID对应的资源 {paper_id: {'file_path': str, 'file_id': str, 'vector_store_id': str}}

    def get_or_upload_file(self, file_path, paper_id=None):
        """获取或上传文件，避免重复上传，并记录论文ID映射"""
        if file_path in self.uploaded_files:
            print(f"♻️ 复用已上传的文件: {self.uploaded_files[file_path]}")
            file_id = self.uploaded_files[file_path]
        else:
            print(f"🔄 首次上传文件: {file_path}")
            file_response = client.files.create(
                file=open(file_path, "rb"),
                purpose="assistants"
            )
            file_id = file_response.id
            self.uploaded_files[file_path] = file_id
            print(f"✅ 文件上传完成: {file_id}")

        # 记录论文ID与资源的映射关系
        if paper_id is not None:
            if paper_id not in self.paper_resources:
                self.paper_resources[paper_id] = {}
            self.paper_resources[paper_id]['file_path'] = file_path
            self.paper_resources[paper_id]['file_id'] = file_id

        return file_id

    def get_or_create_vector_store(self, file_path, store_name, paper_id=None):
        """获取或创建vector store，避免重复创建，并记录论文ID映射"""
        if file_path in self.vector_stores:
            print(f"♻️ 复用已有的 Vector Store: {self.vector_stores[file_path]}")
            vector_store_id = self.vector_stores[file_path]
        else:
            print(f"🔄 创建新的 Vector Store: {store_name}")
            vector_store = client.vector_stores.create(name=store_name)
            vector_store_id = vector_store.id

            # 上传文件到vector store
            file_batch = client.vector_stores.file_batches.upload_and_poll(
                vector_store_id=vector_store_id,
                files=[open(file_path, "rb")]
            )

            self.vector_stores[file_path] = vector_store_id
            print(f"✅ Vector Store 创建完成: {vector_store_id}, 状态: {file_batch.status}")

        # 记录论文ID与资源的映射关系
        if paper_id is not None:
            if paper_id not in self.paper_resources:
                self.paper_resources[paper_id] = {}
            self.paper_resources[paper_id]['vector_store_id'] = vector_store_id

        return vector_store_id

    def cleanup_paper_resources(self, paper_id):
        """清理指定论文ID的资源（文件和vector store），但保留助手"""
        if paper_id not in self.paper_resources:
            print(f"⚠️ 论文ID {paper_id} 没有找到对应的资源")
            return

        paper_resource = self.paper_resources[paper_id]
        print(f"🧹 开始清理论文 {paper_id} 的资源...")

        # 删除vector store
        if 'vector_store_id' in paper_resource:
            vector_store_id = paper_resource['vector_store_id']
            try:
                client.vector_stores.delete(vector_store_id)
                print(f"🗑️ 已删除 Vector Store: {vector_store_id}")

                # 从映射中移除
                file_path = paper_resource.get('file_path')
                if file_path and file_path in self.vector_stores:
                    del self.vector_stores[file_path]
            except Exception as e:
                print(f"⚠️ 删除 Vector Store 失败: {e}")

        # 删除上传的文件
        if 'file_id' in paper_resource:
            file_id = paper_resource['file_id']
            try:
                client.files.delete(file_id)
                print(f"🗑️ 已删除文件: {file_id}")

                # 从映射中移除
                file_path = paper_resource.get('file_path')
                if file_path and file_path in self.uploaded_files:
                    del self.uploaded_files[file_path]
            except Exception as e:
                print(f"⚠️ 删除文件失败: {e}")

        # 从论文资源映射中移除
        del self.paper_resources[paper_id]
        print(f"✅ 论文 {paper_id} 的资源清理完成")

    def cleanup_all_papers_keep_assistants(self):
        """清理所有论文的文件和vector store，但保留助手"""
        paper_ids = list(self.paper_resources.keys())
        for paper_id in paper_ids:
            self.cleanup_paper_resources(paper_id)
        print("✅ 所有论文资源清理完成，助手已保留")

    def get_paper_resource_info(self, paper_id=None):
        """获取论文资源信息"""
        if paper_id:
            if paper_id in self.paper_resources:
                return self.paper_resources[paper_id]
            else:
                print(f"⚠️ 论文ID {paper_id} 没有找到")
                return None
        else:
            return {
                "论文资源": self.paper_resources,
                "助手数量": len(self.assistants),
                "文件数量": len(self.uploaded_files),
                "Vector Store数量": len(self.vector_stores)
            }

# 使用增强版分析器替换原有的
paper_analyzer = PaperAnalyzerEnhanced()

# %%
# 更新演示函数以使用增强版分析器
def run_enhanced_demo():
    answers = []
    try:
        # 加载问题
        multi_choice_questions = json.load(open("D:\\workspace\\pycharm_project\\paper-parser\\multi_choice_questions.json", encoding='utf-8'))
        sorted_questions = sorted(multi_choice_questions, key=lambda x: int(x["paper_id"]))

        for paper in sorted_questions:
            paper_id = paper["paper_id"]
            q, definitions = parse_question(paper)
            answers_details = {
                "paper_id": paper_id,
                "question": q,
            }

            file_dir = os.path.join(paper_base_path, paper_id)
            file_path = os.path.join(file_dir, os.listdir(file_dir)[0])
            print(f"📄 论文文件路径: {file_path}")

            # 使用增强版分析器，传入论文ID
            file_id = paper_analyzer.get_or_upload_file(file_path, paper_id=paper_id)
            vector_store_id = paper_analyzer.get_or_create_vector_store(file_path, f"vector_store_{paper_id}", paper_id=paper_id)
            assistant_id = paper_analyzer.get_or_create_assistant(vector_store_id, file_id)

            if not assistant_id:
                print("❌ 无法创建助手，跳过...")
                break

            # 创建线程
            thread = paper_analyzer.create_thread()
            if not thread:
                print("❌ 无法创建线程，跳过...")
                break

            print(f"❓ 问题: {q}")
            print(f"📋 定义数量: {len(definitions)}")

            for idx, definition in enumerate(definitions):
                print(f"\n🔄 处理定义 {idx+1}: {definition[:100]}...")

                try:
                    # 发送消息
                    message = paper_analyzer.send_message(
                        thread.id,
                        f"{q}\n{definition}"
                    )

                    if not message:
                        print("❌ 发送消息失败")
                        continue

                    # 运行助手
                    run = paper_analyzer.run_assistant(thread.id, assistant_id)

                    if not run:
                        print("❌ 运行助手失败")
                        continue

                    # 等待完成
                    # print("⏳ 等待助手回复...")
                    max_attempts = 30
                    attempts = 0

                    while attempts < max_attempts:
                        run_status = paper_analyzer.get_run_status(thread.id, run.id)

                        if not run_status:
                            print("❌ 无法获取运行状态")
                            break

                        status_icons = {
                            "queued": "⏳",
                            "in_progress": "🔄",
                            "completed": "✅",
                            "failed": "❌",
                            "cancelled": "🚫",
                            "requires_action": "🔧"
                        }
                        icon = status_icons.get(run_status.status, "🔍")
                        print(f"{icon} 状态: {run_status.status}")

                        if run_status.status in ["completed", "failed", "cancelled"]:
                            break
                        elif run_status.status == "requires_action":
                            print(f"🔧 需要操作: {run_status.required_action}")
                            break

                        time.sleep(wait_time)
                        attempts += 1

                    if run_status.status == "completed":
                        # 获取回复
                        messages = paper_analyzer.get_messages(thread.id)
                        if messages:
                            for msg in messages.data:
                                if msg.role == "assistant":
                                    response_text = msg.content[0].text.value
                                    # print(f"\n💡 助手回复: {response_text}")

                                    try:
                                        resp = json.loads(remove_markdown(response_text))
                                        answers_details[definition[0]] = {
                                            "answer": resp["answer"],
                                            "reason": resp["reason"]
                                        }
                                        print(f"✅ 答案解析成功: {resp['answer']}")
                                    except json.JSONDecodeError:
                                        print("⚠️ 回复不是有效的JSON格式，保存原始回复")
                                        answers_details[definition] = {
                                            "answer": "解析失败",
                                            "reason": response_text
                                        }
                                    break
                    else:
                        print(f"❌ 运行未完成，状态: {run_status.status}")
                        if hasattr(run_status, 'last_error') and run_status.last_error:
                            print(f"错误详情: {run_status.last_error}")

                except Exception as e:
                    print(f"❌ 处理定义时出错: {e}")
                    continue

            answers.append(answers_details)
            fo_answers = formatted_answer(answers)
            to_file(answers, fo_answers)
            # 显示资源信息
            print("\n📊 当前资源状态:")
            print(json.dumps(paper_analyzer.get_paper_resource_info(), indent=2, ensure_ascii=False))
            resource_status = paper_analyzer.get_paper_resource_info()
            if resource_status['文件数量'] > 2:
                removed_id = list(resource_status["论文资源"].keys())[0]
                cleanup_paper_by_id(removed_id)
                print(f"🗑️ 已清理论文ID: {removed_id}")

        # print("\n🎉 === 最终结果 ===")
        # print(json.dumps(answers, indent=2, ensure_ascii=False))

        return answers

    except Exception as e:
        print(f"❌ 演示运行出错: {e}")
        import traceback
        traceback.print_exc()
        return answers

# 清理函数
def cleanup_paper_by_id(paper_id):
    """清理指定论文ID的资源"""
    paper_analyzer.cleanup_paper_resources(paper_id)

def cleanup_all_papers():
    """清理所有论文资源但保留助手"""
    paper_analyzer.cleanup_all_papers_keep_assistants()

def cleanup_everything():
    """清理所有资源包括助手"""
    paper_analyzer.cleanup_resources()

print("✅ 增强版演示函数已准备好")
print("🎯 运行 run_enhanced_demo() 来测试新功能")
print("🧹 运行 cleanup_paper_by_id('0') 来清理论文0的资源")
print("🧹 运行 cleanup_all_papers() 来清理所有论文但保留助手")
print("🧹 运行 cleanup_everything() 来清理所有资源")
# Out:
# ✅ 增强版演示函数已准备好
# 🎯 运行 run_enhanced_demo() 来测试新功能
# 🧹 运行 cleanup_paper_by_id('0') 来清理论文0的资源
# 🧹 运行 cleanup_all_papers() 来清理所有论文但保留助手
# 🧹 运行 cleanup_everything() 来清理所有资源

# %%
# cleanup_updated()
answers = run_enhanced_demo()
# Out:
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\0\2024.acl-long.820.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\0\2024.acl-long.820.pdf
# ✅ 文件上传完成: file-Bwmr1R7g73BLDhJpwern1e
# 🔄 创建新的 Vector Store: vector_store_0
# ✅ Vector Store 创建完成: vs_68462c69a818819197ed97b21d7c35ec, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_XXnwzUvvUm73pmmTldifAuxR
# ❓ 问题: Which of the following factors may cause multilingual large language models to show English bias when processing non-English languages?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. The model's training data mainly consists of English text....
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. The model uses English as the central language in the middle layer for semantic understanding and...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. In the model's word embedding space, English word embeddings are more densely distributed and eas...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. The model translates non-English text into English before translating it into the target language...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "0": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\0\\2024.acl-long.820.pdf",
#       "file_id": "file-Bwmr1R7g73BLDhJpwern1e",
#       "vector_store_id": "vs_68462c69a818819197ed97b21d7c35ec"
#     }
#   },
#   "助手数量": 1,
#   "文件数量": 1,
#   "Vector Store数量": 1
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\0\2024.acl-long.820.pdf
# ♻️ 复用已上传的文件: file-Bwmr1R7g73BLDhJpwern1e
# ♻️ 复用已有的 Vector Store: vs_68462c69a818819197ed97b21d7c35ec
# ❓ 问题: Which of the following best describes the three-phase process observed in Llama-2 models when processing non-English prompts?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Input tokens are first mapped to a language-agnostic space, then refined using syntactic rules, a...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. Latent embeddings start in input space, transition to a concept space biased toward English, and ...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. The model implicitly tranfroms input to English via middle-layer attention heads, processes it in...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. Early layers prioritize grammatical structure, middle layers focus on cross-lingual token alignme...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "0": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\0\\2024.acl-long.820.pdf",
#       "file_id": "file-Bwmr1R7g73BLDhJpwern1e",
#       "vector_store_id": "vs_68462c69a818819197ed97b21d7c35ec"
#     }
#   },
#   "助手数量": 1,
#   "文件数量": 1,
#   "Vector Store数量": 1
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\0\2024.acl-long.820.pdf
# ♻️ 复用已上传的文件: file-Bwmr1R7g73BLDhJpwern1e
# ♻️ 复用已有的 Vector Store: vs_68462c69a818819197ed97b21d7c35ec
# ❓ 问题: Which of the following statements are supported by the study?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Intermediate layers of Llama-2 exhibit higher probabilities for English tokens than the input lan...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. The model’s "concept space" is entirely language-agnostic and shows no bias toward English....
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 3: C. Token energy (proximity to output embeddings) sharply increases in the final layers, aligning wit...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. Early-layer embeddings are highly aligned with output token distributions, resulting in low entro...
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "0": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\0\\2024.acl-long.820.pdf",
#       "file_id": "file-Bwmr1R7g73BLDhJpwern1e",
#       "vector_store_id": "vs_68462c69a818819197ed97b21d7c35ec"
#     }
#   },
#   "助手数量": 1,
#   "文件数量": 1,
#   "Vector Store数量": 1
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\1\2402.11541v4.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\1\2402.11541v4.pdf
# ✅ 文件上传完成: file-VxzFVtqp8Sj9DainJPMzfX
# 🔄 创建新的 Vector Store: vector_store_1
# ✅ Vector Store 创建完成: vs_68462d1b025481919327d3407e09c608, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_G1fj2PHj6MIjscw8z87nJXkU
# ❓ 问题: Which of the following statements about LLMs understanding different input formats of KGs are correct?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. LLMs with larger parameters are more robust to noisy or incomplete knowledge graphs when the inpu...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 2: B. Large language models are better able to capture answer-related information when processing linea...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. Converting knowledge graphs to natural language text can reduce semantic gaps and improve the per...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. Different large language models have different preferences for different ways of organizing tripl...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "0": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\0\\2024.acl-long.820.pdf",
#       "file_id": "file-Bwmr1R7g73BLDhJpwern1e",
#       "vector_store_id": "vs_68462c69a818819197ed97b21d7c35ec"
#     },
#     "1": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\1\\2402.11541v4.pdf",
#       "file_id": "file-VxzFVtqp8Sj9DainJPMzfX",
#       "vector_store_id": "vs_68462d1b025481919327d3407e09c608"
#     }
#   },
#   "助手数量": 2,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\1\2402.11541v4.pdf
# ♻️ 复用已上传的文件: file-VxzFVtqp8Sj9DainJPMzfX
# ♻️ 复用已有的 Vector Store: vs_68462d1b025481919327d3407e09c608
# ❓ 问题: Which of the following statements are correct about how LLMs use KG information for question answering?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Linearized triplets are less likely to introduce noise than natural language text when used as in...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. When dealing with multi-hop questions, knowledge provided in the form of natural language text ma...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. Different LLMs show consistent preferences when dealing with sorted linearized triplets, which su...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. For linearized triplets, the attention mechanism of LLMs tends to focus more on the parts related...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "0": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\0\\2024.acl-long.820.pdf",
#       "file_id": "file-Bwmr1R7g73BLDhJpwern1e",
#       "vector_store_id": "vs_68462c69a818819197ed97b21d7c35ec"
#     },
#     "1": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\1\\2402.11541v4.pdf",
#       "file_id": "file-VxzFVtqp8Sj9DainJPMzfX",
#       "vector_store_id": "vs_68462d1b025481919327d3407e09c608"
#     }
#   },
#   "助手数量": 2,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\1\2402.11541v4.pdf
# ♻️ 复用已上传的文件: file-VxzFVtqp8Sj9DainJPMzfX
# ♻️ 复用已有的 Vector Store: vs_68462d1b025481919327d3407e09c608
# ❓ 问题: According to the research in the paper, which of the following conclusions about the combination of large language models (LLMs) and knowledge graphs (KGs) are correct? (Multiple choice)
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Linearized triples (such as (head entity, relation, tail entity)) are more effective than natural...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. LLMs with larger parameters (such as GPT-4) are less robust to noisy or missing triples....
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 3: C. Natural language text (such as manually written documents) can significantly improve the performa...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. LLMs are more sensitive to irrelevant information in natural language text when answering multi-h...
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "0": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\0\\2024.acl-long.820.pdf",
#       "file_id": "file-Bwmr1R7g73BLDhJpwern1e",
#       "vector_store_id": "vs_68462c69a818819197ed97b21d7c35ec"
#     },
#     "1": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\1\\2402.11541v4.pdf",
#       "file_id": "file-VxzFVtqp8Sj9DainJPMzfX",
#       "vector_store_id": "vs_68462d1b025481919327d3407e09c608"
#     }
#   },
#   "助手数量": 2,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\2\2405.12523v3.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\2\2405.12523v3.pdf
# ✅ 文件上传完成: file-SAiX8ye43HCSMuLoBJhSYw
# 🔄 创建新的 Vector Store: vector_store_2
# ✅ Vector Store 创建完成: vs_68462db25d0881918f12190f71176a44, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_JGIY0Z8QwCp6abyyZVgi0Yrb
# ❓ 问题: According to the paper, what are some primary advantages of using Dual Masked KL-divergence in SIU?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. It allows the model to reduce the probability of targeted concept tokens without corrupting unrel...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. It compresses the model size during unlearning, leading to a faster inference speed....
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 3: C. It applies both token-level masking and vocabulary-level masking to manage the trade-off between ...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. It enforces the model to exactly copy the output probabilities from the original model for all to...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "0": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\0\\2024.acl-long.820.pdf",
#       "file_id": "file-Bwmr1R7g73BLDhJpwern1e",
#       "vector_store_id": "vs_68462c69a818819197ed97b21d7c35ec"
#     },
#     "1": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\1\\2402.11541v4.pdf",
#       "file_id": "file-VxzFVtqp8Sj9DainJPMzfX",
#       "vector_store_id": "vs_68462d1b025481919327d3407e09c608"
#     },
#     "2": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\2\\2405.12523v3.pdf",
#       "file_id": "file-SAiX8ye43HCSMuLoBJhSYw",
#       "vector_store_id": "vs_68462db25d0881918f12190f71176a44"
#     }
#   },
#   "助手数量": 3,
#   "文件数量": 3,
#   "Vector Store数量": 3
# }
# 🧹 开始清理论文 0 的资源...
# 🗑️ 已删除 Vector Store: vs_68462c69a818819197ed97b21d7c35ec
# 🗑️ 已删除文件: file-Bwmr1R7g73BLDhJpwern1e
# ✅ 论文 0 的资源清理完成
# 🗑️ 已清理论文ID: 0
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\2\2405.12523v3.pdf
# ♻️ 复用已上传的文件: file-SAiX8ye43HCSMuLoBJhSYw
# ♻️ 复用已有的 Vector Store: vs_68462db25d0881918f12190f71176a44
# ❓ 问题: What are the main evaluation criteria proposed by the authors in MMUBench for assessing unlearning methods in Multimodal LLMs?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Efficacy, which checks whether the model forgets the targeted concept in known images....
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. Efficacy, which checks whether the model forgets the targeted concept in known images....
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. Fluency, which verifies if the overall language quality remains coherent post-unlearning....
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. Carbon footprint, which tracks the environmental cost of the unlearning steps....
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "1": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\1\\2402.11541v4.pdf",
#       "file_id": "file-VxzFVtqp8Sj9DainJPMzfX",
#       "vector_store_id": "vs_68462d1b025481919327d3407e09c608"
#     },
#     "2": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\2\\2405.12523v3.pdf",
#       "file_id": "file-SAiX8ye43HCSMuLoBJhSYw",
#       "vector_store_id": "vs_68462db25d0881918f12190f71176a44"
#     }
#   },
#   "助手数量": 3,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\2\2405.12523v3.pdf
# ♻️ 复用已上传的文件: file-SAiX8ye43HCSMuLoBJhSYw
# ♻️ 复用已有的 Vector Store: vs_68462db25d0881918f12190f71176a44
# ❓ 问题: Based on the experiments comparing SIU to baseline approaches such as Gradient Ascent and GA+KL, which statements are accurate?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. GA typically leads to extreme responses like repeated tokens or whitespace....
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. SIU consistently preserves model utility and diversity better than GA or GA+KL....
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. GA+KL completely eliminates any possibility of recalling the targeted concept in unseen scenarios...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. Both GA and GA+KL fail to maintain coherent outputs when unlearning multiple concepts simultaneou...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "1": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\1\\2402.11541v4.pdf",
#       "file_id": "file-VxzFVtqp8Sj9DainJPMzfX",
#       "vector_store_id": "vs_68462d1b025481919327d3407e09c608"
#     },
#     "2": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\2\\2405.12523v3.pdf",
#       "file_id": "file-SAiX8ye43HCSMuLoBJhSYw",
#       "vector_store_id": "vs_68462db25d0881918f12190f71176a44"
#     }
#   },
#   "助手数量": 3,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\3\2402.14835v1.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\3\2402.14835v1.pdf
# ✅ 文件上传完成: file-VAphoqQZtiLhyumzHgX6Jk
# 🔄 创建新的 Vector Store: vector_store_3
# ✅ Vector Store 创建完成: vs_68462e5324f88191ab3d31a09ebc56c8, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_jrvbU45k0Mz037xjp5Cq3Hnx
# ❓ 问题: Which of the following statements accurately describe the three tasks introduced in the MIKE benchmark—Vanilla Name Answering , Entity-Level Caption , and Complex-Scenario Recognition ?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. VNA specifically tests a model’s ability to return a concise and correct entity name when given a...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. ELC is primarily focused on confirming whether a specific entity appears in a crowded scene of mu...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 3: C. CSR requires the model not only to detect whether the target entity is present among several enti...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. ELC demands the model to generate a descriptive sentence that explicitly identifies the fine-grai...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "1": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\1\\2402.11541v4.pdf",
#       "file_id": "file-VxzFVtqp8Sj9DainJPMzfX",
#       "vector_store_id": "vs_68462d1b025481919327d3407e09c608"
#     },
#     "2": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\2\\2405.12523v3.pdf",
#       "file_id": "file-SAiX8ye43HCSMuLoBJhSYw",
#       "vector_store_id": "vs_68462db25d0881918f12190f71176a44"
#     },
#     "3": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\3\\2402.14835v1.pdf",
#       "file_id": "file-VAphoqQZtiLhyumzHgX6Jk",
#       "vector_store_id": "vs_68462e5324f88191ab3d31a09ebc56c8"
#     }
#   },
#   "助手数量": 4,
#   "文件数量": 3,
#   "Vector Store数量": 3
# }
# 🧹 开始清理论文 1 的资源...
# 🗑️ 已删除 Vector Store: vs_68462d1b025481919327d3407e09c608
# 🗑️ 已删除文件: file-VxzFVtqp8Sj9DainJPMzfX
# ✅ 论文 1 的资源清理完成
# 🗑️ 已清理论文ID: 1
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\3\2402.14835v1.pdf
# ♻️ 复用已上传的文件: file-VAphoqQZtiLhyumzHgX6Jk
# ♻️ 复用已有的 Vector Store: vs_68462e5324f88191ab3d31a09ebc56c8
# ❓ 问题: From the experiments conducted on BLIP-2 and MiniGPT-4, which of the following observations are supported by the paper?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Model size is not the sole determinant of better editing performance....
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. Entity-Level Captioning tends to be more challenging than simple name identification....
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. Once edited, MLLMs never degrade on out-of-scope examples....
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. Editing the LLM layers generally outperforms editing only the visual encoder for FG knowledge....
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "2": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\2\\2405.12523v3.pdf",
#       "file_id": "file-SAiX8ye43HCSMuLoBJhSYw",
#       "vector_store_id": "vs_68462db25d0881918f12190f71176a44"
#     },
#     "3": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\3\\2402.14835v1.pdf",
#       "file_id": "file-VAphoqQZtiLhyumzHgX6Jk",
#       "vector_store_id": "vs_68462e5324f88191ab3d31a09ebc56c8"
#     }
#   },
#   "助手数量": 4,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\3\2402.14835v1.pdf
# ♻️ 复用已上传的文件: file-VAphoqQZtiLhyumzHgX6Jk
# ♻️ 复用已有的 Vector Store: vs_68462e5324f88191ab3d31a09ebc56c8
# ❓ 问题: What are potential advantages of applying Multi-Step Editing (as described in MIKE) when refining the model’s knowledge of fine-grained entities?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. It may allow the model to better capture diverse visual attributes of the target entity....
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. It dramatically reduces the total training time compared to single-step editing....
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 3: C. It tends to improve Reliability and Image Generality with only a slight trade-off in Locality....
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. It is primarily designed to remove unrelated knowledge from the model’s memory....
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "2": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\2\\2405.12523v3.pdf",
#       "file_id": "file-SAiX8ye43HCSMuLoBJhSYw",
#       "vector_store_id": "vs_68462db25d0881918f12190f71176a44"
#     },
#     "3": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\3\\2402.14835v1.pdf",
#       "file_id": "file-VAphoqQZtiLhyumzHgX6Jk",
#       "vector_store_id": "vs_68462e5324f88191ab3d31a09ebc56c8"
#     }
#   },
#   "助手数量": 4,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\5\2310.06671v2.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\5\2310.06671v2.pdf
# ✅ 文件上传完成: file-CnmokTzTkB4qcXe7yT1Jhn
# 🔄 创建新的 Vector Store: vector_store_5
# ✅ Vector Store 创建完成: vs_68462ee4e6fc81919c1fdc5b9d47ac64, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_VX2H7qK53gy7xvq6zkDgpFUe
# ❓ 问题: Which evaluation metrics are used to measure KoPA's performance?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. MRR...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 2: B. Precision...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. Hits@10...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. Recall...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "2": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\2\\2405.12523v3.pdf",
#       "file_id": "file-SAiX8ye43HCSMuLoBJhSYw",
#       "vector_store_id": "vs_68462db25d0881918f12190f71176a44"
#     },
#     "3": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\3\\2402.14835v1.pdf",
#       "file_id": "file-VAphoqQZtiLhyumzHgX6Jk",
#       "vector_store_id": "vs_68462e5324f88191ab3d31a09ebc56c8"
#     },
#     "5": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\5\\2310.06671v2.pdf",
#       "file_id": "file-CnmokTzTkB4qcXe7yT1Jhn",
#       "vector_store_id": "vs_68462ee4e6fc81919c1fdc5b9d47ac64"
#     }
#   },
#   "助手数量": 5,
#   "文件数量": 3,
#   "Vector Store数量": 3
# }
# 🧹 开始清理论文 2 的资源...
# 🗑️ 已删除 Vector Store: vs_68462db25d0881918f12190f71176a44
# 🗑️ 已删除文件: file-SAiX8ye43HCSMuLoBJhSYw
# ✅ 论文 2 的资源清理完成
# 🗑️ 已清理论文ID: 2
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\5\2310.06671v2.pdf
# ♻️ 复用已上传的文件: file-CnmokTzTkB4qcXe7yT1Jhn
# ♻️ 复用已有的 Vector Store: vs_68462ee4e6fc81919c1fdc5b9d47ac64
# ❓ 问题: To improve the performance of LLMs in KG completion tasks, which of the following strategies are highlighted in the paper to enhance the model’s ability to handle structured knowledge?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Direct fine-tuning of LLMs on KG data, which improves the model's capacity to understand the rela...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. Leveraging external knowledge sources, such as knowledge graphs, to complement the LLM's training...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. The integration of entity linking and relational reasoning mechanisms into LLMs, allowing them to...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. Utilizing the encoder-decoder architecture of the LLM to directly predict missing links in the KG...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "3": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\3\\2402.14835v1.pdf",
#       "file_id": "file-VAphoqQZtiLhyumzHgX6Jk",
#       "vector_store_id": "vs_68462e5324f88191ab3d31a09ebc56c8"
#     },
#     "5": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\5\\2310.06671v2.pdf",
#       "file_id": "file-CnmokTzTkB4qcXe7yT1Jhn",
#       "vector_store_id": "vs_68462ee4e6fc81919c1fdc5b9d47ac64"
#     }
#   },
#   "助手数量": 5,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\5\2310.06671v2.pdf
# ♻️ 复用已上传的文件: file-CnmokTzTkB4qcXe7yT1Jhn
# ♻️ 复用已有的 Vector Store: vs_68462ee4e6fc81919c1fdc5b9d47ac64
# ❓ 问题: In the paper 'Making Large Language Models Perform Better in Knowledge Graph Completion,' which of the following approaches are proposed to enhance the ability of large language models (LLMs) to complete missing links in knowledge graphs?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Fine-tuning the LLM on domain-specific corpora to incorporate domain knowledge that might not be ...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. Applying transfer learning from existing large-scale knowledge graph completion models to improve...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. Employing an augmented training approach that incorporates both the textual descriptions and stru...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. Using a specialized attention mechanism that focuses on relevant entities and relations in the kn...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "3": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\3\\2402.14835v1.pdf",
#       "file_id": "file-VAphoqQZtiLhyumzHgX6Jk",
#       "vector_store_id": "vs_68462e5324f88191ab3d31a09ebc56c8"
#     },
#     "5": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\5\\2310.06671v2.pdf",
#       "file_id": "file-CnmokTzTkB4qcXe7yT1Jhn",
#       "vector_store_id": "vs_68462ee4e6fc81919c1fdc5b9d47ac64"
#     }
#   },
#   "助手数量": 5,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\5\2310.06671v2.pdf
# ♻️ 复用已上传的文件: file-CnmokTzTkB4qcXe7yT1Jhn
# ♻️ 复用已有的 Vector Store: vs_68462ee4e6fc81919c1fdc5b9d47ac64
# ❓ 问题: In the paper 'Making Large Language Models Perform Better in Knowledge Graph Completion,' which of the following are identified as novel contributions in extending existing LLM paradigms for knowledge graph completion ?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. The paper introduces the first extensive investigation of LLM-based KGC methods, incorporating KG...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# ✅ 状态: completed
# ⚠️ 回复不是有效的JSON格式，保存原始回复
#
# 🔄 处理定义 2: B. It focuses on adapting existing paradigms such as ICL and IT for KGC by utilizing additional text...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. The paper emphasizes using solely the LLM’s internal knowledge to complete knowledge graph tasks,...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. It proposes a method to augment LLMs' reasoning abilities by incorporating both textual and struc...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "3": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\3\\2402.14835v1.pdf",
#       "file_id": "file-VAphoqQZtiLhyumzHgX6Jk",
#       "vector_store_id": "vs_68462e5324f88191ab3d31a09ebc56c8"
#     },
#     "5": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\5\\2310.06671v2.pdf",
#       "file_id": "file-CnmokTzTkB4qcXe7yT1Jhn",
#       "vector_store_id": "vs_68462ee4e6fc81919c1fdc5b9d47ac64"
#     }
#   },
#   "助手数量": 5,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\5\2310.06671v2.pdf
# ♻️ 复用已上传的文件: file-CnmokTzTkB4qcXe7yT1Jhn
# ♻️ 复用已有的 Vector Store: vs_68462ee4e6fc81919c1fdc5b9d47ac64
# ❓ 问题: In the paper 'Making Large Language Models Perform Better in Knowledge Graph Completion,' which of the following findings are highlighted in the main experiment for the triple classification task, as shown in Table 3 and Figure 3?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. KoPA achieves significant improvements in accuracy and F1-score compared to all 16 baseline model...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. The performance of LLMs in the triple classification task is significantly improved by incorporat...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. Despite the use of additional textual prompts in the structure-aware IT method, its performance s...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. In the inductive setting experiments with varying inductive rates , KoPA shows less performance d...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "3": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\3\\2402.14835v1.pdf",
#       "file_id": "file-VAphoqQZtiLhyumzHgX6Jk",
#       "vector_store_id": "vs_68462e5324f88191ab3d31a09ebc56c8"
#     },
#     "5": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\5\\2310.06671v2.pdf",
#       "file_id": "file-CnmokTzTkB4qcXe7yT1Jhn",
#       "vector_store_id": "vs_68462ee4e6fc81919c1fdc5b9d47ac64"
#     }
#   },
#   "助手数量": 5,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\6\2023.findings-emnlp.631.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\6\2023.findings-emnlp.631.pdf
# ✅ 文件上传完成: file-68sjHXN99NYu25mZhYzxqL
# 🔄 创建新的 Vector Store: vector_store_6
# ✅ Vector Store 创建完成: vs_6846302dea90819196bfbef32af39cfe, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_AeUBxjDwVsVX7zwUOSkQ7vTR
# ❓ 问题: Which techniques are key components of the Kg-GPT framework for enhancing reasoning over knowledge graphs?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Structured prompting...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. Adaptive retrieval mechanisms...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. Graph-based data augmentation...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. Incorporation of graph structure embeddings into LLM inputs...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "3": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\3\\2402.14835v1.pdf",
#       "file_id": "file-VAphoqQZtiLhyumzHgX6Jk",
#       "vector_store_id": "vs_68462e5324f88191ab3d31a09ebc56c8"
#     },
#     "5": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\5\\2310.06671v2.pdf",
#       "file_id": "file-CnmokTzTkB4qcXe7yT1Jhn",
#       "vector_store_id": "vs_68462ee4e6fc81919c1fdc5b9d47ac64"
#     },
#     "6": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\6\\2023.findings-emnlp.631.pdf",
#       "file_id": "file-68sjHXN99NYu25mZhYzxqL",
#       "vector_store_id": "vs_6846302dea90819196bfbef32af39cfe"
#     }
#   },
#   "助手数量": 6,
#   "文件数量": 3,
#   "Vector Store数量": 3
# }
# 🧹 开始清理论文 3 的资源...
# 🗑️ 已删除 Vector Store: vs_68462e5324f88191ab3d31a09ebc56c8
# 🗑️ 已删除文件: file-VAphoqQZtiLhyumzHgX6Jk
# ✅ 论文 3 的资源清理完成
# 🗑️ 已清理论文ID: 3
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\7\2308.07269v3.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\7\2308.07269v3.pdf
# ✅ 文件上传完成: file-Maz4dPXAQMGa3sTKfLmuPr
# 🔄 创建新的 Vector Store: vector_store_7
# ✅ Vector Store 创建完成: vs_684630708768819195d1f391ff4f3316, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_YKuzn6XxRN5Wzh5J2H2RBx33
# ❓ 问题: Which of the following challenges does the SIU method address?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Limited training data availability...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. Model degradation due to meaningless outputs...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. High computational cost of retraining from scratch...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. Memory limitations of large-scale pretraining...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "5": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\5\\2310.06671v2.pdf",
#       "file_id": "file-CnmokTzTkB4qcXe7yT1Jhn",
#       "vector_store_id": "vs_68462ee4e6fc81919c1fdc5b9d47ac64"
#     },
#     "6": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\6\\2023.findings-emnlp.631.pdf",
#       "file_id": "file-68sjHXN99NYu25mZhYzxqL",
#       "vector_store_id": "vs_6846302dea90819196bfbef32af39cfe"
#     },
#     "7": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\7\\2308.07269v3.pdf",
#       "file_id": "file-Maz4dPXAQMGa3sTKfLmuPr",
#       "vector_store_id": "vs_684630708768819195d1f391ff4f3316"
#     }
#   },
#   "助手数量": 7,
#   "文件数量": 3,
#   "Vector Store数量": 3
# }
# 🧹 开始清理论文 5 的资源...
# 🗑️ 已删除 Vector Store: vs_68462ee4e6fc81919c1fdc5b9d47ac64
# 🗑️ 已删除文件: file-CnmokTzTkB4qcXe7yT1Jhn
# ✅ 论文 5 的资源清理完成
# 🗑️ 已清理论文ID: 5
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\8\2402.12869v2.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\8\2402.12869v2.pdf
# ✅ 文件上传完成: file-XXBP8eevavVopgMnB253or
# 🔄 创建新的 Vector Store: vector_store_8
# ✅ Vector Store 创建完成: vs_684630b968c88191b9c13b15786c99c2, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_pjVd0a2SOeJzOnzENsktz4Xo
# ❓ 问题: Under the Retrieval-Augmented Generation framework, which methods perform the best?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Markdown...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. Template...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 3: C. TPLM-based...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. LLM-based...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "6": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\6\\2023.findings-emnlp.631.pdf",
#       "file_id": "file-68sjHXN99NYu25mZhYzxqL",
#       "vector_store_id": "vs_6846302dea90819196bfbef32af39cfe"
#     },
#     "7": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\7\\2308.07269v3.pdf",
#       "file_id": "file-Maz4dPXAQMGa3sTKfLmuPr",
#       "vector_store_id": "vs_684630708768819195d1f391ff4f3316"
#     },
#     "8": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\8\\2402.12869v2.pdf",
#       "file_id": "file-XXBP8eevavVopgMnB253or",
#       "vector_store_id": "vs_684630b968c88191b9c13b15786c99c2"
#     }
#   },
#   "助手数量": 8,
#   "文件数量": 3,
#   "Vector Store数量": 3
# }
# 🧹 开始清理论文 6 的资源...
# 🗑️ 已删除 Vector Store: vs_6846302dea90819196bfbef32af39cfe
# 🗑️ 已删除文件: file-68sjHXN99NYu25mZhYzxqL
# ✅ 论文 6 的资源清理完成
# 🗑️ 已清理论文ID: 6
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\8\2402.12869v2.pdf
# ♻️ 复用已上传的文件: file-XXBP8eevavVopgMnB253or
# ♻️ 复用已有的 Vector Store: vs_684630b968c88191b9c13b15786c99c2
# ❓ 问题: Under the DSFT or RAG frameworks, which combinations of Table-to-Text methods and models scored over 4 in human evaluations?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Markdown+Llama2-7B+RAG...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 2: B. Template+Llama2-70B+DSFT...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 3: C. TPLM-based+Llama2-7B+DSFT...
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. LLM-based+Llama2-70B+RAG...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "7": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\7\\2308.07269v3.pdf",
#       "file_id": "file-Maz4dPXAQMGa3sTKfLmuPr",
#       "vector_store_id": "vs_684630708768819195d1f391ff4f3316"
#     },
#     "8": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\8\\2402.12869v2.pdf",
#       "file_id": "file-XXBP8eevavVopgMnB253or",
#       "vector_store_id": "vs_684630b968c88191b9c13b15786c99c2"
#     }
#   },
#   "助手数量": 8,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\9\2402.13492v3.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\9\2402.13492v3.pdf
# ✅ 文件上传完成: file-LCJYad5fGwCrux32HmhUpK
# 🔄 创建新的 Vector Store: vector_store_9
# ✅ Vector Store 创建完成: vs_6846313ef4a881918dd197efafa99e58, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_IxrIN29mR14xw7HTazrBqCfT
# ❓ 问题: According to the paper, which factors influence whether retrieval augmentation improves language model performance?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Popularity of the entity-relation pairs...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 2: B. The size of the language model...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. The presence of multi-hop reasoning in the query...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. The effectiveness of the retriever in retrieving relevant information...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "7": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\7\\2308.07269v3.pdf",
#       "file_id": "file-Maz4dPXAQMGa3sTKfLmuPr",
#       "vector_store_id": "vs_684630708768819195d1f391ff4f3316"
#     },
#     "8": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\8\\2402.12869v2.pdf",
#       "file_id": "file-XXBP8eevavVopgMnB253or",
#       "vector_store_id": "vs_684630b968c88191b9c13b15786c99c2"
#     },
#     "9": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\9\\2402.13492v3.pdf",
#       "file_id": "file-LCJYad5fGwCrux32HmhUpK",
#       "vector_store_id": "vs_6846313ef4a881918dd197efafa99e58"
#     }
#   },
#   "助手数量": 9,
#   "文件数量": 3,
#   "Vector Store数量": 3
# }
# 🧹 开始清理论文 7 的资源...
# 🗑️ 已删除 Vector Store: vs_684630708768819195d1f391ff4f3316
# 🗑️ 已删除文件: file-Maz4dPXAQMGa3sTKfLmuPr
# ✅ 论文 7 的资源清理完成
# 🗑️ 已清理论文ID: 7
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\10\2023.emnlp-main.537.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\10\2023.emnlp-main.537.pdf
# ✅ 文件上传完成: file-7ksjsYhh7Cya2ChGnvus6V
# 🔄 创建新的 Vector Store: vector_store_10
# ✅ Vector Store 创建完成: vs_6846318595788191b31e5a12bdc3265e, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_DZxMDmkllZaJVBOhLrQUUPGR
# ❓ 问题: Which techniques are introduced in the paper to enhance KG-to-text generation?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Planning scorer for selecting the best linearized sequence...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. Graph neural networks for encoding knowledge graphs...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. Contrastive learning for distinguishing similar input KGs...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. Relative distance encoding in graph structure-aware attention...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "8": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\8\\2402.12869v2.pdf",
#       "file_id": "file-XXBP8eevavVopgMnB253or",
#       "vector_store_id": "vs_684630b968c88191b9c13b15786c99c2"
#     },
#     "9": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\9\\2402.13492v3.pdf",
#       "file_id": "file-LCJYad5fGwCrux32HmhUpK",
#       "vector_store_id": "vs_6846313ef4a881918dd197efafa99e58"
#     },
#     "10": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\10\\2023.emnlp-main.537.pdf",
#       "file_id": "file-7ksjsYhh7Cya2ChGnvus6V",
#       "vector_store_id": "vs_6846318595788191b31e5a12bdc3265e"
#     }
#   },
#   "助手数量": 10,
#   "文件数量": 3,
#   "Vector Store数量": 3
# }
# 🧹 开始清理论文 8 的资源...
# 🗑️ 已删除 Vector Store: vs_684630b968c88191b9c13b15786c99c2
# 🗑️ 已删除文件: file-XXBP8eevavVopgMnB253or
# ✅ 论文 8 的资源清理完成
# 🗑️ 已清理论文ID: 8
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\11\2023.findings-emnlp.493.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\11\2023.findings-emnlp.493.pdf
# ✅ 文件上传完成: file-JXfjYitSue3ZKDK6jiVaCY
# 🔄 创建新的 Vector Store: vector_store_11
# ✅ Vector Store 创建完成: vs_684631bc0cd08191a05de3fbb683bb34, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_UMcxFvnB3o6vfhOOiZXyPKVX
# ❓ 问题: To which tasks is the framework of this paper applicable?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Cell Type Classification...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. Table Type Classification...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. Table QA...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. Table2Text...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "9": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\9\\2402.13492v3.pdf",
#       "file_id": "file-LCJYad5fGwCrux32HmhUpK",
#       "vector_store_id": "vs_6846313ef4a881918dd197efafa99e58"
#     },
#     "10": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\10\\2023.emnlp-main.537.pdf",
#       "file_id": "file-7ksjsYhh7Cya2ChGnvus6V",
#       "vector_store_id": "vs_6846318595788191b31e5a12bdc3265e"
#     },
#     "11": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\11\\2023.findings-emnlp.493.pdf",
#       "file_id": "file-JXfjYitSue3ZKDK6jiVaCY",
#       "vector_store_id": "vs_684631bc0cd08191a05de3fbb683bb34"
#     }
#   },
#   "助手数量": 11,
#   "文件数量": 3,
#   "Vector Store数量": 3
# }
# 🧹 开始清理论文 9 的资源...
# 🗑️ 已删除 Vector Store: vs_6846313ef4a881918dd197efafa99e58
# 🗑️ 已删除文件: file-LCJYad5fGwCrux32HmhUpK
# ✅ 论文 9 的资源清理完成
# 🗑️ 已清理论文ID: 9
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\11\2023.findings-emnlp.493.pdf
# ♻️ 复用已上传的文件: file-JXfjYitSue3ZKDK6jiVaCY
# ♻️ 复用已有的 Vector Store: vs_684631bc0cd08191a05de3fbb683bb34
# ❓ 问题: To which tasks is the framework of this paper inapplicable?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Cell Type Classification...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 2: B. Table Type Classification...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. Table QA...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. Table2Text...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "10": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\10\\2023.emnlp-main.537.pdf",
#       "file_id": "file-7ksjsYhh7Cya2ChGnvus6V",
#       "vector_store_id": "vs_6846318595788191b31e5a12bdc3265e"
#     },
#     "11": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\11\\2023.findings-emnlp.493.pdf",
#       "file_id": "file-JXfjYitSue3ZKDK6jiVaCY",
#       "vector_store_id": "vs_684631bc0cd08191a05de3fbb683bb34"
#     }
#   },
#   "助手数量": 11,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\12\2403.19723v2.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\12\2403.19723v2.pdf
# ✅ 文件上传完成: file-QfpHTJ63hUJH26tu35LR94
# 🔄 创建新的 Vector Store: vector_store_12
# ✅ Vector Store 创建完成: vs_6846324a6fa8819190dea15bd9baccd4, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_lgyoQkoBPIu6ElHDSFbQ094V
# ❓ 问题: Which datasets contain hierarchical tables?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. IM-TQA...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. WTQ (Raw)...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. WTQ (Flatten)...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. HiTab...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "10": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\10\\2023.emnlp-main.537.pdf",
#       "file_id": "file-7ksjsYhh7Cya2ChGnvus6V",
#       "vector_store_id": "vs_6846318595788191b31e5a12bdc3265e"
#     },
#     "11": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\11\\2023.findings-emnlp.493.pdf",
#       "file_id": "file-JXfjYitSue3ZKDK6jiVaCY",
#       "vector_store_id": "vs_684631bc0cd08191a05de3fbb683bb34"
#     },
#     "12": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\12\\2403.19723v2.pdf",
#       "file_id": "file-QfpHTJ63hUJH26tu35LR94",
#       "vector_store_id": "vs_6846324a6fa8819190dea15bd9baccd4"
#     }
#   },
#   "助手数量": 12,
#   "文件数量": 3,
#   "Vector Store数量": 3
# }
# 🧹 开始清理论文 10 的资源...
# 🗑️ 已删除 Vector Store: vs_6846318595788191b31e5a12bdc3265e
# 🗑️ 已删除文件: file-7ksjsYhh7Cya2ChGnvus6V
# ✅ 论文 10 的资源清理完成
# 🗑️ 已清理论文ID: 10
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\13\2403.19305v2.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\13\2403.19305v2.pdf
# ✅ 文件上传完成: file-3nEHbFFnmsHXPkaKuVvKxS
# 🔄 创建新的 Vector Store: vector_store_13
# ✅ Vector Store 创建完成: vs_6846327cac908191994a3d9f3376e1b7, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_OcFVZ6lmetGjiNM3i1o4Z1kv
# ❓ 问题: Based on the experimental results of the MATEval framework (Tables 1, 2, 3), which strategy combinations show the largest improvement in Spearman correlation coefficient (ρ) compared to the second-best strategy (Δρ≥0.1)?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. SR+CoT on 'Repetition ' and 'Inappropriate Lexical Choice ' in the Ant dataset...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# ✅ 状态: completed
# ⚠️ 回复不是有效的JSON格式，保存原始回复
#
# 🔄 处理定义 2: B. SR+CoT on 'Logical Inconsistency ' in the ROC dataset and 'Logical Inconsistency ' in the LOT dat...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# ✅ 状态: completed
# ⚠️ 回复不是有效的JSON格式，保存原始回复
#
# 🔄 处理定义 3: C. SR+CoT on 'Discontinuity ' and 'Repetition ' in the Ant dataset...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ⚠️ 回复不是有效的JSON格式，保存原始回复
#
# ...
# ♻️ 复用已上传的文件: file-SApATAVsJwvCrmKCgHXhQT
# ♻️ 复用已有的 Vector Store: vs_68466001a5788191bdfee321953bc9e8
# ❓ 问题: Which of the following statements about the SEM-based architectures and their training objectives are supported by the paper?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. The sign2sem module uses a Siamese network pretrained on raw text data to minimize the cosine sim...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. The sem2text module employs a cross-entropy loss for text reconstruction, with pretrained mBART d...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. The multitask sign2(sem+text) approach combines mean squared error loss for sentence embedding al...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. Multilingual training with merged datasets consistently improves translation quality compared to ...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "80": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\80\\2406.10486v1.pdf",
#       "file_id": "file-V31CqmpJj2A29DR5KNwkrm",
#       "vector_store_id": "vs_68465f664fc88191bf919313200daded"
#     },
#     "81": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\81\\2024.acl-short.40.pdf",
#       "file_id": "file-SApATAVsJwvCrmKCgHXhQT",
#       "vector_store_id": "vs_68466001a5788191bdfee321953bc9e8"
#     }
#   },
#   "助手数量": 76,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\82\2403.01289v2.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\82\2403.01289v2.pdf
# ✅ 文件上传完成: file-JimojvQ5CBZYou5ERsQcFv
# 🔄 创建新的 Vector Store: vector_store_82
# ✅ Vector Store 创建完成: vs_6846607a88948191ba498f5ea7693f12, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_nnK5UkGB4EtdnPMpuHSV7XRy
# ❓ 问题: Based on the intrinsic evaluation metrics, which of the following effects are observed when applying the 'least tokens' inference strategy across tokenizers?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. It consistently improves cognitive plausibility metrics by aligning segmentations with human lexi...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. It reduces the average number of tokens per word more effectively than likelihood-based or dropou...
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. It introduces significant morphological misalignment compared to deterministic merge rules for BP...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. It underperforms longest prefix inference for SaGe tokenizers in retaining contextualized morphol...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "80": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\80\\2406.10486v1.pdf",
#       "file_id": "file-V31CqmpJj2A29DR5KNwkrm",
#       "vector_store_id": "vs_68465f664fc88191bf919313200daded"
#     },
#     "81": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\81\\2024.acl-short.40.pdf",
#       "file_id": "file-SApATAVsJwvCrmKCgHXhQT",
#       "vector_store_id": "vs_68466001a5788191bdfee321953bc9e8"
#     },
#     "82": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\82\\2403.01289v2.pdf",
#       "file_id": "file-JimojvQ5CBZYou5ERsQcFv",
#       "vector_store_id": "vs_6846607a88948191ba498f5ea7693f12"
#     }
#   },
#   "助手数量": 77,
#   "文件数量": 3,
#   "Vector Store数量": 3
# }
# 🧹 开始清理论文 80 的资源...
# 🗑️ 已删除 Vector Store: vs_68465f664fc88191bf919313200daded
# 🗑️ 已删除文件: file-V31CqmpJj2A29DR5KNwkrm
# ✅ 论文 80 的资源清理完成
# 🗑️ 已清理论文ID: 80
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\82\2403.01289v2.pdf
# ♻️ 复用已上传的文件: file-JimojvQ5CBZYou5ERsQcFv
# ♻️ 复用已有的 Vector Store: vs_6846607a88948191ba498f5ea7693f12
# ❓ 问题: Which of the following statements about the performance of tokenizer inference methods in the benchmark evaluation are correct?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. SaGe tokenizers using the longest prefix inference method achieve the highest morphological align...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. The least tokens inference strategy demonstrates superior cognitive plausibility across BPE, Word...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. BPE tokenizers employing dropout merge rules exhibit higher Rényi efficiency scores than those us...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. Greedy inference methods such as longest token and longest suffix universally minimize the averag...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "81": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\81\\2024.acl-short.40.pdf",
#       "file_id": "file-SApATAVsJwvCrmKCgHXhQT",
#       "vector_store_id": "vs_68466001a5788191bdfee321953bc9e8"
#     },
#     "82": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\82\\2403.01289v2.pdf",
#       "file_id": "file-JimojvQ5CBZYou5ERsQcFv",
#       "vector_store_id": "vs_6846607a88948191ba498f5ea7693f12"
#     }
#   },
#   "助手数量": 77,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\83\2024.acl-short.74.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\83\2024.acl-short.74.pdf
# ✅ 文件上传完成: file-B1ifYP7LezCqDyBC57Y9rm
# 🔄 创建新的 Vector Store: vector_store_83
# ✅ Vector Store 创建完成: vs_684660dfb3e0819180661f4ea89c4582, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_9yZxMRIRjzUKjMJOIYVVE1Yv
# ❓ 问题: Which of the following statements about German dialect speakers' attitudes toward hypothetical language technologies (LTs) are supported by the survey findings?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Dialect speakers strongly favor technologies that process dialectal input, such as virtual assist...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. Speech-to-text systems that transcribe dialectal audio into written Standard German are more pref...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 3: C. Machine translation tools that convert dialect texts into foreign languages are viewed as equally...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. Spellcheckers for dialects are widely opposed due to concerns about enforcing arbitrary standardi...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "81": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\81\\2024.acl-short.40.pdf",
#       "file_id": "file-SApATAVsJwvCrmKCgHXhQT",
#       "vector_store_id": "vs_68466001a5788191bdfee321953bc9e8"
#     },
#     "82": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\82\\2403.01289v2.pdf",
#       "file_id": "file-JimojvQ5CBZYou5ERsQcFv",
#       "vector_store_id": "vs_6846607a88948191ba498f5ea7693f12"
#     },
#     "83": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\83\\2024.acl-short.74.pdf",
#       "file_id": "file-B1ifYP7LezCqDyBC57Y9rm",
#       "vector_store_id": "vs_684660dfb3e0819180661f4ea89c4582"
#     }
#   },
#   "助手数量": 78,
#   "文件数量": 3,
#   "Vector Store数量": 3
# }
# 🧹 开始清理论文 81 的资源...
# 🗑️ 已删除 Vector Store: vs_68466001a5788191bdfee321953bc9e8
# 🗑️ 已删除文件: file-SApATAVsJwvCrmKCgHXhQT
# ✅ 论文 81 的资源清理完成
# 🗑️ 已清理论文ID: 81
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\84\2403.00794v2.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\84\2403.00794v2.pdf
# ✅ 文件上传完成: file-FTdU2yoY56HHfHsFjyWDY1
# 🔄 创建新的 Vector Store: vector_store_84
# ✅ Vector Store 创建完成: vs_68466129b6ec81919074a8d749358376, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_2ni0S4Ok4gusebkpdtYoyLix
# ❓ 问题: Which of the following statements about the capabilities of LLMs in humor editing and dataset creation, as discussed in the paper, are correct?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. LLMs like GPT-4 and GPT-3.5 consistently outperform human satirical writers in generating humorou...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 2: B. Synthetic unfunned data generated by GPT-4 results in humor classifiers with smaller accuracy dro...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 3: C. The ROBERTA-SWAP baseline method, which replaces tokens based on low probability ratios, achieves...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. GPT-4’s ability to 'unfun' humor generalizes to code-mixed English-Hindi tweets, producing synthe...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "82": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\82\\2403.01289v2.pdf",
#       "file_id": "file-JimojvQ5CBZYou5ERsQcFv",
#       "vector_store_id": "vs_6846607a88948191ba498f5ea7693f12"
#     },
#     "83": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\83\\2024.acl-short.74.pdf",
#       "file_id": "file-B1ifYP7LezCqDyBC57Y9rm",
#       "vector_store_id": "vs_684660dfb3e0819180661f4ea89c4582"
#     },
#     "84": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\84\\2403.00794v2.pdf",
#       "file_id": "file-FTdU2yoY56HHfHsFjyWDY1",
#       "vector_store_id": "vs_68466129b6ec81919074a8d749358376"
#     }
#   },
#   "助手数量": 79,
#   "文件数量": 3,
#   "Vector Store数量": 3
# }
# 🧹 开始清理论文 82 的资源...
# 🗑️ 已删除 Vector Store: vs_6846607a88948191ba498f5ea7693f12
# 🗑️ 已删除文件: file-JimojvQ5CBZYou5ERsQcFv
# ✅ 论文 82 的资源清理完成
# 🗑️ 已清理论文ID: 82
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\85\2405.10989v1.pdf
# 🔄 首次上传文件: D:\workspace\pycharm_project\paper-parser\papers\85\2405.10989v1.pdf
# ✅ 文件上传完成: file-1gZAPXaSHpgsYaVfpJsnsT
# 🔄 创建新的 Vector Store: vector_store_85
# ✅ Vector Store 创建完成: vs_6846615b0a0881919dbd2c679230092f, 状态: completed
# 🔄 创建新的助手...
# ✅ 使用 beta assistants API 创建成功
# ✅ 助手创建完成: asst_J1JH2WGWkPAF2inffqLx4343
# ❓ 问题: Which of the following statements accurately describe the adversarial training objectives and experimental outcomes of the proposed privacy neuron localization method?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. The L0 regularization term penalizes the number of localized neurons to minimize their overlap wi...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. The adversarial loss function preserves the model’s language modeling ability by maximizing the l...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. The hyperparameter η controlling the penalty on localized neurons is set to zero to prioritize PI...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. Deactivating localized privacy neurons reduces PII leakage metrics (MA and EL) while maintaining ...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "83": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\83\\2024.acl-short.74.pdf",
#       "file_id": "file-B1ifYP7LezCqDyBC57Y9rm",
#       "vector_store_id": "vs_684660dfb3e0819180661f4ea89c4582"
#     },
#     "84": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\84\\2403.00794v2.pdf",
#       "file_id": "file-FTdU2yoY56HHfHsFjyWDY1",
#       "vector_store_id": "vs_68466129b6ec81919074a8d749358376"
#     },
#     "85": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\85\\2405.10989v1.pdf",
#       "file_id": "file-1gZAPXaSHpgsYaVfpJsnsT",
#       "vector_store_id": "vs_6846615b0a0881919dbd2c679230092f"
#     }
#   },
#   "助手数量": 80,
#   "文件数量": 3,
#   "Vector Store数量": 3
# }
# 🧹 开始清理论文 83 的资源...
# 🗑️ 已删除 Vector Store: vs_684660dfb3e0819180661f4ea89c4582
# 🗑️ 已删除文件: file-B1ifYP7LezCqDyBC57Y9rm
# ✅ 论文 83 的资源清理完成
# 🗑️ 已清理论文ID: 83
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\85\2405.10989v1.pdf
# ♻️ 复用已上传的文件: file-1gZAPXaSHpgsYaVfpJsnsT
# ♻️ 复用已有的 Vector Store: vs_6846615b0a0881919dbd2c679230092f
# ❓ 问题: Which of the following statements about the characteristics and findings of privacy neurons in LLMs are correct?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Exceeding a 2% ratio of deactivated privacy neurons leads to entanglement with general knowledge,...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. Privacy neurons are distributed across all layers of the model but exhibit a reduced concentratio...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 3: C. The majority of privacy neurons responsible for PII memorization are localized within the MLP com...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 4: D. Privacy neurons demonstrate specificity, with distinct subsets of neurons memorizing different ca...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "84": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\84\\2403.00794v2.pdf",
#       "file_id": "file-FTdU2yoY56HHfHsFjyWDY1",
#       "vector_store_id": "vs_68466129b6ec81919074a8d749358376"
#     },
#     "85": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\85\\2405.10989v1.pdf",
#       "file_id": "file-1gZAPXaSHpgsYaVfpJsnsT",
#       "vector_store_id": "vs_6846615b0a0881919dbd2c679230092f"
#     }
#   },
#   "助手数量": 80,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }
# 📄 论文文件路径: D:\workspace\pycharm_project\paper-parser\papers\85\2405.10989v1.pdf
# ♻️ 复用已上传的文件: file-1gZAPXaSHpgsYaVfpJsnsT
# ♻️ 复用已有的 Vector Store: vs_6846615b0a0881919dbd2c679230092f
# ❓ 问题: Which of the following statements accurately describe the experimental outcomes and mitigation strategies for PII leakage proposed in the paper?
# 📋 定义数量: 4
#
# 🔄 处理定义 1: A. Deactivating localized privacy neurons reduces PII memorization accuracy by over 50% while preser...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: correct
#
# 🔄 处理定义 2: B. The proposed method outperforms Scrubbed Fine-tuning and DPD in reducing EL for PII across all te...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 3: C. Penalizing the number of localized neurons via hyperparameter η ensures that fewer than 1% of tot...
# ⏳ 状态: queued
# 🔄 状态: in_progress
# 🔄 状态: in_progress
# ✅ 状态: completed
# ✅ 答案解析成功: incorrect
#
# 🔄 处理定义 4: D. Privacy neurons identified for email addresses exhibit minimal overlap with those responsible for...
# ⏳ 状态: queued
# ✅ 状态: completed
# ✅ 答案解析成功: correct
# ✅ 已保存分析结果到 D:\workspace\pycharm_project\paper-parser\analysis_answers.json
# ✅ 已保存格式化答案到 D:\workspace\pycharm_project\paper-parser\analysis_answers_formatted.json
#
# 📊 当前资源状态:
# {
#   "论文资源": {
#     "84": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\84\\2403.00794v2.pdf",
#       "file_id": "file-FTdU2yoY56HHfHsFjyWDY1",
#       "vector_store_id": "vs_68466129b6ec81919074a8d749358376"
#     },
#     "85": {
#       "file_path": "D:\\workspace\\pycharm_project\\paper-parser\\papers\\85\\2405.10989v1.pdf",
#       "file_id": "file-1gZAPXaSHpgsYaVfpJsnsT",
#       "vector_store_id": "vs_6846615b0a0881919dbd2c679230092f"
#     }
#   },
#   "助手数量": 80,
#   "文件数量": 2,
#   "Vector Store数量": 2
# }

# %%
import json
formatted_answer(answers)
to_file(answers, formatted_answer(answers))

# %%
cleanup_everything()
